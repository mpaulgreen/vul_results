# %%
import requests

def fetch_cves(limit=10000):
    base_url = "https://access.redhat.com/labs/securitydataapi/cve.json"
    cves = []
    page = 1
    per_page = 100  # Number of CVEs per page (max allowed by the API)

    while len(cves) < limit:
        url = f"{base_url}?page={page}&per_page={per_page}"
        response = requests.get(url)
        
        if response.status_code != 200:
            print(f"Failed to fetch data: {response.status_code}")
            break
        
        data = response.json()
        if not data:
            break  # No more data available
        
        cves.extend(data)
        page += 1

        print(f"Fetched {len(cves)} CVEs so far...")

        if len(data) < per_page:
            break  # No more pages available

    return cves[:limit]

# Fetch the first 20,000 CVEs
cves = fetch_cves(limit=20000)

# Print the total number of CVEs fetched
print(f"Total CVEs fetched: {len(cves)}")
# Out:
# Fetched 100 CVEs so far...
# Fetched 200 CVEs so far...
# Fetched 300 CVEs so far...
# Fetched 400 CVEs so far...
# Fetched 500 CVEs so far...
# Fetched 600 CVEs so far...
# Fetched 700 CVEs so far...
# Fetched 800 CVEs so far...
# Fetched 900 CVEs so far...
# Fetched 1000 CVEs so far...
# Fetched 1100 CVEs so far...
# Fetched 1200 CVEs so far...
# Fetched 1300 CVEs so far...
# Fetched 1400 CVEs so far...
# Fetched 1500 CVEs so far...
# Fetched 1600 CVEs so far...
# Fetched 1700 CVEs so far...
# Fetched 1800 CVEs so far...
# Fetched 1900 CVEs so far...
# Fetched 2000 CVEs so far...
# Fetched 2100 CVEs so far...
# Fetched 2200 CVEs so far...
# Fetched 2300 CVEs so far...
# Fetched 2400 CVEs so far...
# Fetched 2500 CVEs so far...
# Fetched 2600 CVEs so far...
# Fetched 2700 CVEs so far...
# Fetched 2800 CVEs so far...
# Fetched 2900 CVEs so far...
# Fetched 3000 CVEs so far...
# Fetched 3100 CVEs so far...
# Fetched 3200 CVEs so far...
# Fetched 3300 CVEs so far...
# Fetched 3400 CVEs so far...
# Fetched 3500 CVEs so far...
# Fetched 3600 CVEs so far...
# Fetched 3700 CVEs so far...
# Fetched 3800 CVEs so far...
# Fetched 3900 CVEs so far...
# Fetched 4000 CVEs so far...
# Fetched 4100 CVEs so far...
# Fetched 4200 CVEs so far...
# Fetched 4300 CVEs so far...
# Fetched 4400 CVEs so far...
# Fetched 4500 CVEs so far...
# Fetched 4600 CVEs so far...
# Fetched 4700 CVEs so far...
# Fetched 4800 CVEs so far...
# Fetched 4900 CVEs so far...
# Fetched 5000 CVEs so far...
# Fetched 5100 CVEs so far...
# Fetched 5200 CVEs so far...
# Fetched 5300 CVEs so far...
# Fetched 5400 CVEs so far...
# Fetched 5500 CVEs so far...
# Fetched 5600 CVEs so far...
# Fetched 5700 CVEs so far...
# Fetched 5800 CVEs so far...
# Fetched 5900 CVEs so far...
# Fetched 6000 CVEs so far...
# Fetched 6100 CVEs so far...
# Fetched 6200 CVEs so far...
# Fetched 6300 CVEs so far...
# Fetched 6400 CVEs so far...
# Fetched 6500 CVEs so far...
# Fetched 6600 CVEs so far...
# Fetched 6700 CVEs so far...
# Fetched 6800 CVEs so far...
# Fetched 6900 CVEs so far...
# Fetched 7000 CVEs so far...
# Fetched 7100 CVEs so far...
# Fetched 7200 CVEs so far...
# Fetched 7300 CVEs so far...
# Fetched 7400 CVEs so far...
# Fetched 7500 CVEs so far...
# Fetched 7600 CVEs so far...
# Fetched 7700 CVEs so far...
# Fetched 7800 CVEs so far...
# Fetched 7900 CVEs so far...
# Fetched 8000 CVEs so far...
# Fetched 8100 CVEs so far...
# Fetched 8200 CVEs so far...
# Fetched 8300 CVEs so far...
# Fetched 8400 CVEs so far...
# Fetched 8500 CVEs so far...
# Fetched 8600 CVEs so far...
# Fetched 8700 CVEs so far...
# Fetched 8800 CVEs so far...
# Fetched 8900 CVEs so far...
# Fetched 9000 CVEs so far...
# Fetched 9100 CVEs so far...
# Fetched 9200 CVEs so far...
# Fetched 9300 CVEs so far...
# Fetched 9400 CVEs so far...
# Fetched 9500 CVEs so far...
# Fetched 9600 CVEs so far...
# Fetched 9700 CVEs so far...
# Fetched 9800 CVEs so far...
# Fetched 9900 CVEs so far...
# Fetched 10000 CVEs so far...
# Fetched 10100 CVEs so far...
# Fetched 10200 CVEs so far...
# Fetched 10300 CVEs so far...
# Fetched 10400 CVEs so far...
# Fetched 10500 CVEs so far...
# Fetched 10600 CVEs so far...
# Fetched 10700 CVEs so far...
# Fetched 10800 CVEs so far...
# Fetched 10900 CVEs so far...
# Fetched 11000 CVEs so far...
# Fetched 11100 CVEs so far...
# Fetched 11200 CVEs so far...
# Fetched 11300 CVEs so far...
# Fetched 11400 CVEs so far...
# Fetched 11500 CVEs so far...
# Fetched 11600 CVEs so far...
# Fetched 11700 CVEs so far...
# Fetched 11800 CVEs so far...
# Fetched 11900 CVEs so far...
# Fetched 12000 CVEs so far...
# Fetched 12100 CVEs so far...
# Fetched 12200 CVEs so far...
# Fetched 12300 CVEs so far...
# Fetched 12400 CVEs so far...
# Fetched 12500 CVEs so far...
# Fetched 12600 CVEs so far...
# Fetched 12700 CVEs so far...
# Fetched 12800 CVEs so far...
# Fetched 12900 CVEs so far...
# Fetched 13000 CVEs so far...
# Fetched 13100 CVEs so far...
# Fetched 13200 CVEs so far...
# Fetched 13300 CVEs so far...
# Fetched 13400 CVEs so far...
# Fetched 13500 CVEs so far...
# Fetched 13600 CVEs so far...
# Fetched 13700 CVEs so far...
# Fetched 13800 CVEs so far...
# Fetched 13900 CVEs so far...
# Fetched 14000 CVEs so far...
# Fetched 14100 CVEs so far...
# Fetched 14200 CVEs so far...
# Fetched 14300 CVEs so far...
# Fetched 14400 CVEs so far...
# Fetched 14500 CVEs so far...
# Fetched 14600 CVEs so far...
# Fetched 14700 CVEs so far...
# Fetched 14800 CVEs so far...
# Fetched 14900 CVEs so far...
# Fetched 15000 CVEs so far...
# Fetched 15100 CVEs so far...
# Fetched 15200 CVEs so far...
# Fetched 15300 CVEs so far...
# Fetched 15400 CVEs so far...
# Fetched 15500 CVEs so far...
# Fetched 15600 CVEs so far...
# Fetched 15700 CVEs so far...
# Fetched 15800 CVEs so far...
# Fetched 15900 CVEs so far...
# Fetched 16000 CVEs so far...
# Fetched 16100 CVEs so far...
# Fetched 16200 CVEs so far...
# Fetched 16300 CVEs so far...
# Fetched 16400 CVEs so far...
# Fetched 16500 CVEs so far...
# Fetched 16600 CVEs so far...
# Fetched 16700 CVEs so far...
# Fetched 16800 CVEs so far...
# Fetched 16900 CVEs so far...
# Fetched 17000 CVEs so far...
# Fetched 17100 CVEs so far...
# Fetched 17200 CVEs so far...
# Fetched 17300 CVEs so far...
# Fetched 17400 CVEs so far...
# Fetched 17500 CVEs so far...
# Fetched 17600 CVEs so far...
# Fetched 17700 CVEs so far...
# Fetched 17800 CVEs so far...
# Fetched 17900 CVEs so far...
# Fetched 18000 CVEs so far...
# Fetched 18100 CVEs so far...
# Fetched 18200 CVEs so far...
# Fetched 18300 CVEs so far...
# Fetched 18400 CVEs so far...
# Fetched 18500 CVEs so far...
# Fetched 18600 CVEs so far...
# Fetched 18700 CVEs so far...
# Fetched 18800 CVEs so far...
# Fetched 18900 CVEs so far...
# Fetched 19000 CVEs so far...
# Fetched 19100 CVEs so far...
# Fetched 19200 CVEs so far...
# Fetched 19300 CVEs so far...
# Fetched 19400 CVEs so far...
# Fetched 19500 CVEs so far...
# Fetched 19600 CVEs so far...
# Fetched 19700 CVEs so far...
# Fetched 19800 CVEs so far...
# Fetched 19900 CVEs so far...
# Fetched 20000 CVEs so far...
# Total CVEs fetched: 20000

# %%
cve_resources=[]
for cve in cves:
    cve_resources.append(cve['resource_url'])

# %%
len(cve_resources)
# Out:
# 20000

# %%
from pandas import DataFrame
cve_names = []
package_names = []
fix_states = []

# %%
PYXIS_URL="https://catalog.redhat.com/api/containers/v1"

# %%
image_tags = []
grades = []

# %%
BAD_GRADES = {'C', 'D', 'E', 'F'}

# Cache to store image data for packages
image_data_cache = {}

for cve_resource in cve_resources:
    cve_response = requests.get(cve_resource)
    security_data = cve_response.json()
    
    if 'package_state' not in security_data:
        continue
    
    for package in security_data['package_state']:
        if package['fix_state'] == 'Affected' and "openshift4/" in package['package_name']:
            package_name = package['package_name']
            
            # Check cache first
            if package_name not in image_data_cache:
                endpoint = f"{PYXIS_URL}/repositories/registry/registry.access.redhat.com/repository/{package_name}/images?page_size=100&sort_by=creation_date[desc]"
                r = requests.get(endpoint)
                image_data = r.json()
                image_data_cache[package_name] = image_data['data'] if image_data.get('data') else []
            
            image_data_list = image_data_cache[package_name]
            
            for data in image_data_list:
                if 'freshness_grades' not in data:
                    continue
                
                for grade in data['freshness_grades']:
                    if grade['grade'] in BAD_GRADES:
                        cve_names.append(security_data['name'])
                        package_names.append(package_name)
                        fix_states.append(package['fix_state'])
                        image_tags.append(data['image_id'])
                        grades.append(grade['grade'])
                        break  # Exit the inner loop once a bad grade is found
                else:
                    continue  # Continue to the next data if no bad grade is found
                break  # Exit the outer loop once a bad grade is found

# %%
len(cve_names) , len(package_names) , len(fix_states) , len(grades), len(image_tags)
# Out:
# (664, 664, 664, 664, 664)

# %%
# !pip install openpyxl

# %%
# security_data['name']+','+package['package_name']+ ','+package['fix_state'] + "\n"
df = DataFrame({'CVE': cve_names, 'package': package_names, 'Fix State': fix_states, 'tag': image_tags, 'grade': grades})
df.to_excel('affected_catchall.xlsx', sheet_name='sheet1', index=False)
